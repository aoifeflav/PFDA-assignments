# %% [markdown]
# # Assignment 3: Domains
# ### Author: Aoife Flavin

# %%
#Data Frames
import pandas as pd

#plotting
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("people-1000.csv")
df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
#
#                            Email            Phone Date of birth  \
# 0            pwarner@example.org     857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net  +1-950-759-8687    1931-07-26
# 2            fhoward@example.org    (599)782-0605    2013-11-25
#
#            Job Title
# 0  Probation officer
# 1             Dancer
# 2               Copy

# %% [markdown]
# Create a new column with just the email domain

# %%
df['domain'] = df['Email'].str.split('@').str[1]
df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2      3  810Ce0F276Badec     Sheryl    Lowery  Female
#
#                            Email            Phone Date of birth  \
# 0            pwarner@example.org     857.139.8239    2014-01-27
# 1  fergusonkatherine@example.net  +1-950-759-8687    1931-07-26
# 2            fhoward@example.org    (599)782-0605    2013-11-25
#
#            Job Title       domain
# 0  Probation officer  example.org
# 1             Dancer  example.net
# 2               Copy  example.org

# %% [markdown]
# Count how many of each domain there is:

# %%
# Count each domain
domain_counts = df['domain'].value_counts()
print(domain_counts)
# Out:
# domain
# example.org    341
# example.com    339
# example.net    320
# Name: count, dtype: int64

# %% [markdown]
# Plot the pie chart
#
# Sources: https://www.w3schools.com/python/matplotlib_pie_charts.asp

# %%
plt.figure(figsize=(10, 8))  # Adjust the figure size to make the chart larger
colors = ["#ff6900","#ff3bbd","#b296ff"]  # Set custom colors for each domain
explode = (0.1, 0.1, 0.1)  # Slightly "explode" each slice to separate them

plt.pie(domain_counts, labels=domain_counts.index, autopct='%1.1f%%', startangle=140,
        colors=colors, explode=explode, shadow=True, wedgeprops={'edgecolor': 'black', 'linewidth': 1.5})

plt.title("Distribution of Email Domains", fontsize=16, fontweight='bold')  # title with large & bold font
plt.legend(title="Email Domains", bbox_to_anchor=(1, 0.5), loc="center left")  # Legend
plt.show()

# %% [markdown]
# end
